# %% [markdown]
# <a href="https://colab.research.google.com/github/valvasm/MIS433FORREAL/blob/main/relational_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Relational Data
#
# In data analysis, you often need to combine multiple data sets to answer the questions that you are interested in.
#
# Collectively, multiple related sets (tables) of data are called relational data. In relational (SQL) databases (DBs), each table is called a relation. Two tables (relations) may have a relationship between each other via a PK (primary key) and a FK (foreign key). It is also not uncommon to have more than two tables related to each other.
#
# To work with relational data, we typically need to perform three families of operations:
# - **Mutating joins**, which add new variables to one data frame from matching observations in another.
# - **Filtering joins**, which filter observations from one data frame based on whether or not they match an observation in the other table.
# - **Set operations**, which treat observations as if they were set elements.
#
# If you have learned relational databases and SQL (Structured Query Language), you should find many of these concepts and operations familiar.
#
# We will use the **nycflights13** package to learn about relational data.

# %%
# !pip install nycflights13
# Out:
# Collecting nycflights13
#   Downloading nycflights13-0.0.3.tar.gz (8.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 60.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from nycflights13) (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24.0->nycflights13) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24.0->nycflights13) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24.0->nycflights13) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24.0->nycflights13) (2026.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=0.24.0->nycflights13) (1.17.0)
# Building wheels for collected packages: nycflights13
#   Building wheel for nycflights13 (setup.py) ... done
#   Created wheel for nycflights13: filename=nycflights13-0.0.3-py3-none-any.whl size=8732722 sha256=df496b1ba86337da86ef774263c23c351b592e3f8e36b691e1ccd2665e642674
#   Stored in directory: /root/.cache/pip/wheels/58/ee/20/7838832df5510701439239ec10c2d8927de32aac2729ce2085
# Successfully built nycflights13
# Installing collected packages: nycflights13
# Successfully installed nycflights13-0.0.3

# %%
import pandas as pd

# Install the "nycflights13" package before you run the following code.
from nycflights13 import flights
from nycflights13 import airlines
from nycflights13 import airports
from nycflights13 import planes
from nycflights13 import weather

# %%
flights.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 3            1022      -18.0      B6     725  N804JB    JFK  BQN     183.0
# 4             837      -25.0      DL     461  N668DN    LGA  ATL     116.0
#
#    distance  hour  minute             time_hour
# 0      1400     5      15  2013-01-01T10:00:00Z
# 1      1416     5      29  2013-01-01T10:00:00Z
# 2      1089     5      40  2013-01-01T10:00:00Z
# 3      1576     5      45  2013-01-01T10:00:00Z
# 4       762     6       0  2013-01-01T11:00:00Z

# %%
airlines.head()
# Out:
#   carrier                    name
# 0      9E       Endeavor Air Inc.
# 1      AA  American Airlines Inc.
# 2      AS    Alaska Airlines Inc.
# 3      B6         JetBlue Airways
# 4      DL    Delta Air Lines Inc.

# %%
airports.head()
# Out:
#    faa                           name        lat        lon   alt  tz dst  \
# 0  04G              Lansdowne Airport  41.130472 -80.619583  1044  -5   A
# 1  06A  Moton Field Municipal Airport  32.460572 -85.680028   264  -6   A
# 2  06C            Schaumburg Regional  41.989341 -88.101243   801  -6   A
# 3  06N                Randall Airport  41.431912 -74.391561   523  -5   A
# 4  09J          Jekyll Island Airport  31.074472 -81.427778    11  -5   A
#
#               tzone
# 0  America/New_York
# 1   America/Chicago
# 2   America/Chicago
# 3  America/New_York
# 4  America/New_York

# %%
planes.head()
# Out:
#   tailnum    year                     type      manufacturer      model  \
# 0  N10156  2004.0  Fixed wing multi engine           EMBRAER  EMB-145XR
# 1  N102UW  1998.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 2  N103US  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 3  N104UW  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 4  N10575  2002.0  Fixed wing multi engine           EMBRAER  EMB-145LR
#
#    engines  seats  speed     engine
# 0        2     55    NaN  Turbo-fan
# 1        2    182    NaN  Turbo-fan
# 2        2    182    NaN  Turbo-fan
# 3        2    182    NaN  Turbo-fan
# 4        2     55    NaN  Turbo-fan

# %%
weather.head()
# Out:
#   origin  year  month  day  hour   temp   dewp  humid  wind_dir  wind_speed  \
# 0    EWR  2013      1    1     1  39.02  26.06  59.37     270.0    10.35702
# 1    EWR  2013      1    1     2  39.02  26.96  61.63     250.0     8.05546
# 2    EWR  2013      1    1     3  39.02  28.04  64.43     240.0    11.50780
# 3    EWR  2013      1    1     4  39.92  28.04  62.21     250.0    12.65858
# 4    EWR  2013      1    1     5  39.02  28.04  64.43     260.0    12.65858
#
#    wind_gust  precip  pressure  visib             time_hour
# 0        NaN     0.0    1012.0   10.0  2013-01-01T06:00:00Z
# 1        NaN     0.0    1012.3   10.0  2013-01-01T07:00:00Z
# 2        NaN     0.0    1012.5   10.0  2013-01-01T08:00:00Z
# 3        NaN     0.0    1012.2   10.0  2013-01-01T09:00:00Z
# 4        NaN     0.0    1011.9   10.0  2013-01-01T10:00:00Z

# %% [markdown]
# The relationships between these tables are shown in the following diagram:

# %%
from IPython.display import Image
Image('https://d33wubrfki0l68.cloudfront.net/245292d1ea724f6c3fd8a92063dcd7bfb9758d02/5751b/diagrams/relational-nycflights.png')

# %% [markdown]
# For nycflights13:
#
# - ``flights`` connects to ``planes`` via a single variable, ``tailnum``.
# - ``flights`` connects to ``airlines`` through the ``carrier`` variable.
# - ``flights`` connects to ``airports`` in two ways: via the ``origin`` and ``dest`` variables.
# - ``flights`` connects to ``weather`` via origin (the location), and ``year``, ``month``, ``day`` and ``hour`` (the time).

# %% [markdown]
# ## Keys
#
# The variables used to connect each pair of tables are called **keys**. A key is a variable (or set of variables) that uniquely identifies an observation.
#
# For example, each plane is uniquely identified by its ``tailnum``. In other cases, multiple variables may be needed. For example, to identify an observation in weather you need five variables: ``year``, ``month``, ``day``, ``hour``, and ``origin``.
#
# There are two types of keys:
# - A primary key uniquely identifies an observation in its own table. For example, in the ``planes`` table, ``tailnum`` is a primary key because it uniquely identifies each plane in the ``planes`` table.
# - A foreign key uniquely identifies an observation in another table. For example, in the ``flights`` table, ``tailnum`` is a foreign key because it matches each flight to a unique plane.
#
# Once you've identified the primary keys in your tables, it is good practice to verify that they do indeed uniquely identify each observation.

# %%
# Count the number of rows in the table "planes"
planes.shape[0]
# Out:
# 3322

# %%
# Count the number of unique values in column "tailnum"
planes.tailnum.nunique()
# Out:
# 3322

# %%
# Count the occurrence of different values in column "tailnum"
planes.tailnum.value_counts()
# Out:
# tailnum
# N999DN    1
# N10156    1
# N102UW    1
# N103US    1
# N104UW    1
#          ..
# N11119    1
# N11113    1
# N11109    1
# N11107    1
# N11106    1
# Name: count, Length: 3322, dtype: int64

# %%
# Try to determine the key for flights: ['year','month','day','carrier','flight']?
flights[['year','month','day','carrier','flight',]].value_counts()
# Out:
# year  month  day  carrier  flight
# 2013  8      15   UA       236       2
#              19   UA       207       2
#       6      15   WN       2269      2
#       8      26   UA       207       2
#              20   UA       635       2
#                                     ..
#       5      4    B6       553       1
#                            547       1
#                            537       1
#                            527       1
#                            625       1
# Name: count, Length: 336752, dtype: int64

# %%
# Adding more variable(s) to make a key?
flights[['year','month','day','carrier','flight','origin']].value_counts()
# Out:
# year  month  day  carrier  flight  origin
# 2013  12     31   YV       3771    LGA       1
#       1      1    9E       3286    JFK       1
#                            3295    JFK       1
#                            3320    JFK       1
#                            3321    JFK       1
#                                             ..
#                            3364    JFK       1
#                            3361    JFK       1
#                            3359    JFK       1
#                            3357    JFK       1
#                            3352    JFK       1
# Name: count, Length: 336776, dtype: int64

# %% [markdown]
# Sometimes a table doesn’t have an explicit primary key: each row is an observation, but no combination of variables reliably identifies it.

# %% [markdown]
# If a table lacks a primary key or a non-composite key, it’s sometimes useful to add one, e.g., its row number. That makes it easier to match observations if you’ve done some filtering and want to check back in with the original data. This is called a **surrogate key**.

# %%
# Add a surrogate key to flights.
flights['id'] = flights.index
flights.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 3            1022      -18.0      B6     725  N804JB    JFK  BQN     183.0
# 4             837      -25.0      DL     461  N668DN    LGA  ATL     116.0
#
#    distance  hour  minute             time_hour  id
# 0      1400     5      15  2013-01-01T10:00:00Z   0
# 1      1416     5      29  2013-01-01T10:00:00Z   1
# 2      1089     5      40  2013-01-01T10:00:00Z   2
# 3      1576     5      45  2013-01-01T10:00:00Z   3
# 4       762     6       0  2013-01-01T11:00:00Z   4

# %% [markdown]
# ## Standard Joins
#
# Join two data sets/tables by the PK-FK relationship.
#
# Create two datasets, ``adf`` and ``bdf``:

# %%
adf = pd.DataFrame(
    [['A',1],
     ['B',2],
     ['C',3]],
    columns=['x1', 'x2'])
adf
# Out:
#   x1  x2
# 0  A   1
# 1  B   2
# 2  C   3

# %%
bdf = pd.DataFrame(
    [['A',True],
     ['B',False],
     ['D',True]],
    columns=['x1', 'x3'])
bdf
# Out:
#   x1     x3
# 0  A   True
# 1  B  False
# 2  D   True

# %% [markdown]
# ### Inner Join
#
# The simplest type of join is the inner join. An inner join matches pairs of observations whenever their keys are equal:

# %%
pd.merge(adf, bdf, how='inner', on='x1')
# Out:
#   x1  x2     x3
# 0  A   1   True
# 1  B   2  False

# %%
# You can do this as well.
adf.merge(bdf, how='inner', on='x1')
# Out:
#   x1  x2     x3
# 0  A   1   True
# 1  B   2  False

# %% [markdown]
# ### Outer Joins
#
# - A left join keeps all observations in adf.
# - A right join keeps all observations in bdf.
# - A full join keeps all observations in adf and bdf.

# %%
# Left join
pd.merge(adf, bdf, how='left', on='x1')
# Out:
#   x1  x2     x3
# 0  A   1   True
# 1  B   2  False
# 2  C   3    NaN

# %%
# Right join
pd.merge(adf, bdf, how='right', on='x1')
# Out:
#   x1   x2     x3
# 0  A  1.0   True
# 1  B  2.0  False
# 2  D  NaN   True

# %%
# Full outer join
pd.merge(adf, bdf, how='outer', on='x1')
# Out:
#   x1   x2     x3
# 0  A  1.0   True
# 1  B  2.0  False
# 2  C  3.0    NaN
# 3  D  NaN   True

# %% [markdown]
# ### Filter Joins

# %%
# All rows in adf that have a match in bdf
adf[adf.x1.isin(bdf.x1)]
# Out:
#   x1  x2
# 0  A   1
# 1  B   2

# %%
# All rows in adf that do not have a match in bdf
adf[~adf.x1.isin(bdf.x1)]
# Out:
#   x1  x2
# 2  C   3

# %% [markdown]
# ## Set-like Operations
#
# In Pandas, the `merge()` method can also be used for set-like operations, such as `union`, `intersection`, and `set-difference`. All these operations work with a complete row, comparing the values of every variable.
#
# Take these as examples:

# %%
xdf = pd.DataFrame(
    [['A',1],
     ['B',2],
     ['C',3]],
    columns=['x1', 'x2'])
xdf
# Out:
#   x1  x2
# 0  A   1
# 1  B   2
# 2  C   3

# %%
ydf = pd.DataFrame(
    [['B',2],
     ['C',3],
     ['D',4]],
    columns=['x1', 'x2'])
ydf
# Out:
#   x1  x2
# 0  B   2
# 1  C   3
# 2  D   4

# %%
# Union: Rows that appear in either or both xdf and ydf
pd.merge(xdf, ydf, how='outer')
# Out:
#   x1  x2
# 0  A   1
# 1  B   2
# 2  C   3
# 3  D   4

# %%
# Intersection: Rows that appear in both xdf and ydf
pd.merge(xdf, ydf)
# Out:
#   x1  x2
# 0  B   2
# 1  C   3

# %%
# Difference: Rows that appear in xdf but not in ydf
pd.merge(xdf, ydf, how='outer', indicator=True).query('_merge == "left_only"').drop(columns=['_merge'])
# Out:
#   x1  x2
# 0  A   1

# %% [markdown]
# ## Appending Rows or Columns to Dataframe
#
# When working with multiple dataframes, we often need to combine them by rows or by columns. This is when we need to use the `concat()` method.

# %%
# xdf and ydf have the same variables (columns)
# Append rows in ydf to xdf
pd.concat([xdf, ydf])
# Out:
#   x1  x2
# 0  A   1
# 1  B   2
# 2  C   3
# 0  B   2
# 1  C   3
# 2  D   4

# %%
# Create a new dataframe zdf
zdf = pd.DataFrame(
    [[True, 4],
     [False, 5],
     [False, 6]],
    columns=['x3','x4'])
zdf
# Out:
#       x3  x4
# 0   True   4
# 1  False   5
# 2  False   6

# %%
# xdf and zdf contain different variables of the same data instances in the same order.
# Append the columns of zdf to xdf
pd.concat([xdf, zdf], axis=1)
# Out:
#   x1  x2     x3  x4
# 0  A   1   True   4
# 1  B   2  False   5
# 2  C   3  False   6

# %% [markdown]
# ## Examples
#
# Let's use merge() on our flights data. For these examples, we’ll make it easier to see what’s going on by creating a narrower dataframe:

# %%
# Create a smaller dataframe
flights2 = flights[['year','month', 'day', 'hour', 'origin', 'dest', 'tailnum', 'carrier']]
flights2
# Out:
#         year  month  day  hour origin dest tailnum carrier
# 0       2013      1    1     5    EWR  IAH  N14228      UA
# 1       2013      1    1     5    LGA  IAH  N24211      UA
# 2       2013      1    1     5    JFK  MIA  N619AA      AA
# 3       2013      1    1     5    JFK  BQN  N804JB      B6
# 4       2013      1    1     6    LGA  ATL  N668DN      DL
# ...      ...    ...  ...   ...    ...  ...     ...     ...
# 336771  2013      9   30    14    JFK  DCA     NaN      9E
# 336772  2013      9   30    22    LGA  SYR     NaN      9E
# 336773  2013      9   30    12    LGA  BNA  N535MQ      MQ
# 336774  2013      9   30    11    LGA  CLE  N511MQ      MQ
# 336775  2013      9   30     8    LGA  RDU  N839MQ      MQ
#
# [336776 rows x 8 columns]

# %% [markdown]
# Imagine you want to add the full airline name to the ``flights2`` data. You can combine the ``airlines`` and ``flights2`` data frames with a left join:

# %%
pd.merge(flights2, airlines, how='left', on='carrier')
# Out:
#         year  month  day  hour origin dest tailnum carrier  \
# 0       2013      1    1     5    EWR  IAH  N14228      UA
# 1       2013      1    1     5    LGA  IAH  N24211      UA
# 2       2013      1    1     5    JFK  MIA  N619AA      AA
# 3       2013      1    1     5    JFK  BQN  N804JB      B6
# 4       2013      1    1     6    LGA  ATL  N668DN      DL
# ...      ...    ...  ...   ...    ...  ...     ...     ...
# 336771  2013      9   30    14    JFK  DCA     NaN      9E
# 336772  2013      9   30    22    LGA  SYR     NaN      9E
# 336773  2013      9   30    12    LGA  BNA  N535MQ      MQ
# 336774  2013      9   30    11    LGA  CLE  N511MQ      MQ
# 336775  2013      9   30     8    LGA  RDU  N839MQ      MQ
#
#                           name
# 0        United Air Lines Inc.
# 1        United Air Lines Inc.
# 2       American Airlines Inc.
# 3              JetBlue Airways
# 4         Delta Air Lines Inc.
# ...                        ...
# 336771       Endeavor Air Inc.
# 336772       Endeavor Air Inc.
# 336773               Envoy Air
# 336774               Envoy Air
# 336775               Envoy Air
#
# [336776 rows x 9 columns]

# %%
# This gives you the same results
flights2.merge(airlines, how='left', on='carrier')
# Out:
#         year  month  day  hour origin dest tailnum carrier  \
# 0       2013      1    1     5    EWR  IAH  N14228      UA
# 1       2013      1    1     5    LGA  IAH  N24211      UA
# 2       2013      1    1     5    JFK  MIA  N619AA      AA
# 3       2013      1    1     5    JFK  BQN  N804JB      B6
# 4       2013      1    1     6    LGA  ATL  N668DN      DL
# ...      ...    ...  ...   ...    ...  ...     ...     ...
# 336771  2013      9   30    14    JFK  DCA     NaN      9E
# 336772  2013      9   30    22    LGA  SYR     NaN      9E
# 336773  2013      9   30    12    LGA  BNA  N535MQ      MQ
# 336774  2013      9   30    11    LGA  CLE  N511MQ      MQ
# 336775  2013      9   30     8    LGA  RDU  N839MQ      MQ
#
#                           name
# 0        United Air Lines Inc.
# 1        United Air Lines Inc.
# 2       American Airlines Inc.
# 3              JetBlue Airways
# 4         Delta Air Lines Inc.
# ...                        ...
# 336771       Endeavor Air Inc.
# 336772       Endeavor Air Inc.
# 336773               Envoy Air
# 336774               Envoy Air
# 336775               Envoy Air
#
# [336776 rows x 9 columns]

# %% [markdown]
# Sometimes, we need to join on multiple columns.

# %%
# For each flight, show the weather of the day as well
pd.merge(flights2, weather, how='left', on=["year", "month", "day", "hour", "origin"])
# Out:
#         year  month  day  hour origin dest tailnum carrier   temp   dewp  \
# 0       2013      1    1     5    EWR  IAH  N14228      UA  39.02  28.04
# 1       2013      1    1     5    LGA  IAH  N24211      UA  39.92  24.98
# 2       2013      1    1     5    JFK  MIA  N619AA      AA  39.02  26.96
# 3       2013      1    1     5    JFK  BQN  N804JB      B6  39.02  26.96
# 4       2013      1    1     6    LGA  ATL  N668DN      DL  39.92  24.98
# ...      ...    ...  ...   ...    ...  ...     ...     ...    ...    ...
# 336771  2013      9   30    14    JFK  DCA     NaN      9E  68.00  55.04
# 336772  2013      9   30    22    LGA  SYR     NaN      9E  64.94  53.06
# 336773  2013      9   30    12    LGA  BNA  N535MQ      MQ  69.08  48.02
# 336774  2013      9   30    11    LGA  CLE  N511MQ      MQ  66.92  48.92
# 336775  2013      9   30     8    LGA  RDU  N839MQ      MQ  60.98  51.08
#
#         humid  wind_dir  wind_speed  wind_gust  precip  pressure  visib  \
# 0       64.43     260.0    12.65858        NaN     0.0    1011.9   10.0
# 1       54.81     250.0    14.96014   21.86482     0.0    1011.4   10.0
# 2       61.63     260.0    14.96014        NaN     0.0    1012.1   10.0
# 3       61.63     260.0    14.96014        NaN     0.0    1012.1   10.0
# 4       54.81     260.0    16.11092   23.01560     0.0    1011.7   10.0
# ...       ...       ...         ...        ...     ...       ...    ...
# 336771  63.21     190.0    11.50780        NaN     0.0    1016.6   10.0
# 336772  65.37     200.0     6.90468        NaN     0.0    1015.8   10.0
# 336773  46.99      70.0     5.75390        NaN     0.0    1016.7   10.0
# 336774  52.35      70.0     8.05546        NaN     0.0    1017.5   10.0
# 336775  69.86       NaN     5.75390        NaN     0.0    1018.6   10.0
#
#                    time_hour
# 0       2013-01-01T10:00:00Z
# 1       2013-01-01T10:00:00Z
# 2       2013-01-01T10:00:00Z
# 3       2013-01-01T10:00:00Z
# 4       2013-01-01T11:00:00Z
# ...                      ...
# 336771  2013-09-30T18:00:00Z
# 336772  2013-10-01T02:00:00Z
# 336773  2013-09-30T16:00:00Z
# 336774  2013-09-30T15:00:00Z
# 336775  2013-09-30T12:00:00Z
#
# [336776 rows x 18 columns]

# %%
# The default, on = None, uses all matching variables that appear in both tables, the so called 'natural join'.
pd.merge(flights2, weather, how='left')
# Out:
#         year  month  day  hour origin dest tailnum carrier   temp   dewp  \
# 0       2013      1    1     5    EWR  IAH  N14228      UA  39.02  28.04
# 1       2013      1    1     5    LGA  IAH  N24211      UA  39.92  24.98
# 2       2013      1    1     5    JFK  MIA  N619AA      AA  39.02  26.96
# 3       2013      1    1     5    JFK  BQN  N804JB      B6  39.02  26.96
# 4       2013      1    1     6    LGA  ATL  N668DN      DL  39.92  24.98
# ...      ...    ...  ...   ...    ...  ...     ...     ...    ...    ...
# 336771  2013      9   30    14    JFK  DCA     NaN      9E  68.00  55.04
# 336772  2013      9   30    22    LGA  SYR     NaN      9E  64.94  53.06
# 336773  2013      9   30    12    LGA  BNA  N535MQ      MQ  69.08  48.02
# 336774  2013      9   30    11    LGA  CLE  N511MQ      MQ  66.92  48.92
# 336775  2013      9   30     8    LGA  RDU  N839MQ      MQ  60.98  51.08
#
#         humid  wind_dir  wind_speed  wind_gust  precip  pressure  visib  \
# 0       64.43     260.0    12.65858        NaN     0.0    1011.9   10.0
# 1       54.81     250.0    14.96014   21.86482     0.0    1011.4   10.0
# 2       61.63     260.0    14.96014        NaN     0.0    1012.1   10.0
# 3       61.63     260.0    14.96014        NaN     0.0    1012.1   10.0
# 4       54.81     260.0    16.11092   23.01560     0.0    1011.7   10.0
# ...       ...       ...         ...        ...     ...       ...    ...
# 336771  63.21     190.0    11.50780        NaN     0.0    1016.6   10.0
# 336772  65.37     200.0     6.90468        NaN     0.0    1015.8   10.0
# 336773  46.99      70.0     5.75390        NaN     0.0    1016.7   10.0
# 336774  52.35      70.0     8.05546        NaN     0.0    1017.5   10.0
# 336775  69.86       NaN     5.75390        NaN     0.0    1018.6   10.0
#
#                    time_hour
# 0       2013-01-01T10:00:00Z
# 1       2013-01-01T10:00:00Z
# 2       2013-01-01T10:00:00Z
# 3       2013-01-01T10:00:00Z
# 4       2013-01-01T11:00:00Z
# ...                      ...
# 336771  2013-09-30T18:00:00Z
# 336772  2013-10-01T02:00:00Z
# 336773  2013-09-30T16:00:00Z
# 336774  2013-09-30T15:00:00Z
# 336775  2013-09-30T12:00:00Z
#
# [336776 rows x 18 columns]

# %% [markdown]
# Sometimes, the column names from the two dataframes may not match. Then, you need to explicitly specify the columns from each side.

# %%
# We want to combine the flights data with the airports data (key: 'faa').
# For origin:
pd.merge(flights2, airports, how='left', left_on='origin', right_on='faa')
# Out:
#         year  month  day  hour origin dest tailnum carrier  faa  \
# 0       2013      1    1     5    EWR  IAH  N14228      UA  EWR
# 1       2013      1    1     5    LGA  IAH  N24211      UA  LGA
# 2       2013      1    1     5    JFK  MIA  N619AA      AA  JFK
# 3       2013      1    1     5    JFK  BQN  N804JB      B6  JFK
# 4       2013      1    1     6    LGA  ATL  N668DN      DL  LGA
# ...      ...    ...  ...   ...    ...  ...     ...     ...  ...
# 336771  2013      9   30    14    JFK  DCA     NaN      9E  JFK
# 336772  2013      9   30    22    LGA  SYR     NaN      9E  LGA
# 336773  2013      9   30    12    LGA  BNA  N535MQ      MQ  LGA
# 336774  2013      9   30    11    LGA  CLE  N511MQ      MQ  LGA
# 336775  2013      9   30     8    LGA  RDU  N839MQ      MQ  LGA
#
#                        name        lat        lon  alt  tz dst  \
# 0       Newark Liberty Intl  40.692500 -74.168667   18  -5   A
# 1                La Guardia  40.777245 -73.872608   22  -5   A
# 2       John F Kennedy Intl  40.639751 -73.778925   13  -5   A
# 3       John F Kennedy Intl  40.639751 -73.778925   13  -5   A
# 4                La Guardia  40.777245 -73.872608   22  -5   A
# ...                     ...        ...        ...  ...  ..  ..
# 336771  John F Kennedy Intl  40.639751 -73.778925   13  -5   A
# 336772           La Guardia  40.777245 -73.872608   22  -5   A
# 336773           La Guardia  40.777245 -73.872608   22  -5   A
# 336774           La Guardia  40.777245 -73.872608   22  -5   A
# 336775           La Guardia  40.777245 -73.872608   22  -5   A
#
#                    tzone
# 0       America/New_York
# 1       America/New_York
# 2       America/New_York
# 3       America/New_York
# 4       America/New_York
# ...                  ...
# 336771  America/New_York
# 336772  America/New_York
# 336773  America/New_York
# 336774  America/New_York
# 336775  America/New_York
#
# [336776 rows x 16 columns]

# %%
# For destination:
pd.merge(flights2, airports, how='left', left_on='dest', right_on='faa')
# Out:
#         year  month  day  hour origin dest tailnum carrier  faa  \
# 0       2013      1    1     5    EWR  IAH  N14228      UA  IAH
# 1       2013      1    1     5    LGA  IAH  N24211      UA  IAH
# 2       2013      1    1     5    JFK  MIA  N619AA      AA  MIA
# 3       2013      1    1     5    JFK  BQN  N804JB      B6  NaN
# 4       2013      1    1     6    LGA  ATL  N668DN      DL  ATL
# ...      ...    ...  ...   ...    ...  ...     ...     ...  ...
# 336771  2013      9   30    14    JFK  DCA     NaN      9E  DCA
# 336772  2013      9   30    22    LGA  SYR     NaN      9E  SYR
# 336773  2013      9   30    12    LGA  BNA  N535MQ      MQ  BNA
# 336774  2013      9   30    11    LGA  CLE  N511MQ      MQ  CLE
# 336775  2013      9   30     8    LGA  RDU  N839MQ      MQ  RDU
#
#                                    name        lat        lon     alt   tz  \
# 0          George Bush Intercontinental  29.984433 -95.341442    97.0 -6.0
# 1          George Bush Intercontinental  29.984433 -95.341442    97.0 -6.0
# 2                            Miami Intl  25.793250 -80.290556     8.0 -5.0
# 3                                   NaN        NaN        NaN     NaN  NaN
# 4       Hartsfield Jackson Atlanta Intl  33.636719 -84.428067  1026.0 -5.0
# ...                                 ...        ...        ...     ...  ...
# 336771    Ronald Reagan Washington Natl  38.852083 -77.037722    15.0 -5.0
# 336772            Syracuse Hancock Intl  43.111187 -76.106311   421.0 -5.0
# 336773                   Nashville Intl  36.124472 -86.678194   599.0 -6.0
# 336774           Cleveland Hopkins Intl  41.411689 -81.849794   791.0 -5.0
# 336775              Raleigh Durham Intl  35.877639 -78.787472   435.0 -5.0
#
#         dst             tzone
# 0         A   America/Chicago
# 1         A   America/Chicago
# 2         A  America/New_York
# 3       NaN               NaN
# 4         A  America/New_York
# ...     ...               ...
# 336771    A  America/New_York
# 336772    A  America/New_York
# 336773    A   America/Chicago
# 336774    A  America/New_York
# 336775    A  America/New_York
#
# [336776 rows x 16 columns]

# %% [markdown]
# ## Exercises

# %%
# Compute the average arrival delay by destination,
# then join with the airports dataframe.
(
flights.groupby('dest')['arr_delay'].mean()
.to_frame()
.merge(airports, how='left', left_on='dest', right_on='faa')
)
# Out:
#      arr_delay  faa                               name        lat         lon  \
# 0     4.381890  ABQ  Albuquerque International Sunport  35.040222 -106.609194
# 1     4.852273  ACK                      Nantucket Mem  41.253053  -70.060181
# 2    14.397129  ALB                        Albany Intl  42.748267  -73.801692
# 3    -2.500000  ANC         Ted Stevens Anchorage Intl  61.174361 -149.996361
# 4    11.300113  ATL    Hartsfield Jackson Atlanta Intl  33.636719  -84.428067
# ..         ...  ...                                ...        ...         ...
# 100   7.408525  TPA                         Tampa Intl  27.975472  -82.533250
# 101  33.659864  TUL                         Tulsa Intl  36.198389  -95.888111
# 102  12.968421  TVC             Cherry Capital Airport  44.741445  -85.582235
# 103  24.069204  TYS                      Mc Ghee Tyson  35.810972  -83.994028
# 104   7.465726  XNA               NW Arkansas Regional  36.281869  -94.306811
#
#         alt   tz dst              tzone
# 0    5355.0 -7.0   A     America/Denver
# 1      48.0 -5.0   A   America/New_York
# 2     285.0 -5.0   A   America/New_York
# 3     152.0 -9.0   A  America/Anchorage
# 4    1026.0 -5.0   A   America/New_York
# ..      ...  ...  ..                ...
# 100    26.0 -5.0   A   America/New_York
# 101   677.0 -6.0   A    America/Chicago
# 102   624.0 -5.0   A   America/New_York
# 103   981.0 -5.0   A   America/New_York
# 104  1287.0 -6.0   A    America/Chicago
#
# [105 rows x 9 columns]

# %%
# Add the fullname of the origin and destination airports to flights.
(
    flights2
    .merge(airports[['faa','name']], how='left', left_on='origin', right_on='faa')
    .merge(airports[['faa','name']], how='left', left_on='dest', right_on='faa')
)
# Out:
#         year  month  day  hour origin dest tailnum carrier faa_x  \
# 0       2013      1    1     5    EWR  IAH  N14228      UA   EWR
# 1       2013      1    1     5    LGA  IAH  N24211      UA   LGA
# 2       2013      1    1     5    JFK  MIA  N619AA      AA   JFK
# 3       2013      1    1     5    JFK  BQN  N804JB      B6   JFK
# 4       2013      1    1     6    LGA  ATL  N668DN      DL   LGA
# ...      ...    ...  ...   ...    ...  ...     ...     ...   ...
# 336771  2013      9   30    14    JFK  DCA     NaN      9E   JFK
# 336772  2013      9   30    22    LGA  SYR     NaN      9E   LGA
# 336773  2013      9   30    12    LGA  BNA  N535MQ      MQ   LGA
# 336774  2013      9   30    11    LGA  CLE  N511MQ      MQ   LGA
# 336775  2013      9   30     8    LGA  RDU  N839MQ      MQ   LGA
#
#                      name_x faa_y                           name_y
# 0       Newark Liberty Intl   IAH     George Bush Intercontinental
# 1                La Guardia   IAH     George Bush Intercontinental
# 2       John F Kennedy Intl   MIA                       Miami Intl
# 3       John F Kennedy Intl   NaN                              NaN
# 4                La Guardia   ATL  Hartsfield Jackson Atlanta Intl
# ...                     ...   ...                              ...
# 336771  John F Kennedy Intl   DCA    Ronald Reagan Washington Natl
# 336772           La Guardia   SYR            Syracuse Hancock Intl
# 336773           La Guardia   BNA                   Nashville Intl
# 336774           La Guardia   CLE           Cleveland Hopkins Intl
# 336775           La Guardia   RDU              Raleigh Durham Intl
#
# [336776 rows x 12 columns]

# %%
# What weather conditions make it more likely to cause a departure delay?
(
    flights.merge(weather, how='left', on=["year", "month", "day", "hour", "origin"])
[['dep_delay','temp', 'dewp', 'humid', 'wind_dir', 'wind_speed',
       'wind_gust', 'precip', 'pressure', 'visib']].corr()
)
# Out:
#             dep_delay      temp      dewp     humid  wind_dir  wind_speed  \
# dep_delay    1.000000  0.061491  0.102353  0.117494 -0.017562    0.047424
# temp         0.061491  1.000000  0.882265  0.035520 -0.099931   -0.146848
# dewp         0.102353  0.882265  1.000000  0.492246 -0.235978   -0.221230
# humid        0.117494  0.035520  0.492246  1.000000 -0.324957   -0.192249
# wind_dir    -0.017562 -0.099931 -0.235978 -0.324957  1.000000    0.341566
# wind_speed   0.047424 -0.146848 -0.221230 -0.192249  0.341566    1.000000
# wind_gust    0.041326 -0.330167 -0.277960  0.053327  0.069168    0.883032
# precip       0.090400  0.010341  0.100632  0.236107 -0.068000    0.037896
# pressure    -0.114237 -0.245974 -0.278175 -0.159277 -0.209285   -0.215353
# visib       -0.094118  0.102372 -0.128334 -0.548684  0.208869    0.058108
#
#             wind_gust    precip  pressure     visib
# dep_delay    0.041326  0.090400 -0.114237 -0.094118
# temp        -0.330167  0.010341 -0.245974  0.102372
# dewp        -0.277960  0.100632 -0.278175 -0.128334
# humid        0.053327  0.236107 -0.159277 -0.548684
# wind_dir     0.069168 -0.068000 -0.209285  0.208869
# wind_speed   0.883032  0.037896 -0.215353  0.058108
# wind_gust    1.000000  0.070128 -0.240627 -0.135805
# precip       0.070128  1.000000 -0.088148 -0.316219
# pressure    -0.240627 -0.088148  1.000000  0.107774
# visib       -0.135805 -0.316219  0.107774  1.000000
